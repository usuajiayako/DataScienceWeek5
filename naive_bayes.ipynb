# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
data = pd.read_csv('food_data.csv')  # load our data
data
# Out:
#            Food  Calories  Calories from Fat  Total Fat  Total Fat.1  Sodium  \
# 0     Asparagus        20                  0        0.0            0       0
# 1   Bell Pepper        25                  0        0.0            0      40
# 2      Broccoli        45                  0        0.5            1      80
# 3        Carrot        30                  0        0.0            0      60
# 4   Cauliflower        25                  0        0.0            0      30
# ..          ...       ...                ...        ...          ...     ...
# 56     Scallops       140                 10        1.0            2     310
# 57       Shrimp       100                 10        1.5            2     240
# 58    Swordfish       120                 50        6.0            9     100
# 59      Tilapia       110                 20        2.5            4      30
# 60         Tuna       130                 15        1.5            2      40
#
# ...

# %%
data.index = data.iloc[:,0] # Name rows as food for reference, making a column to the index
data_to_use = data.iloc[:,3:16]
data_to_target = data.iloc[:,16]

data_to_target
# Out:
# Food
# Asparagus      Vegetables
# Bell Pepper    Vegetables
# Broccoli       Vegetables
# Carrot         Vegetables
# Cauliflower    Vegetables
#                   ...
# Scallops          Seafood
# Shrimp            Seafood
# Swordfish         Seafood
# Tilapia           Seafood
# Tuna              Seafood
# Name: Food Type, Length: 61, dtype: object

# %%
# 70% training, 30% test
X_train, X_test, y_train, y_test = train_test_split(data_to_use, data_to_target, test_size=0.3, random_state=21)

# %%
# define a model (Gaussian model)
gaussian_model = GaussianNB()

# %%
# Training the model
gaussian_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Predict the response
prediction = gaussian_model.predict(X_test)

# %%
# making comparison between actual and prediction
result = {'food_type':y_test, 'pred':prediction}

# %%
# converting the result to dataframe
result_df = pd.DataFrame(result)

# %%
# Checking NB accuracy
print("Accuracy:", metrics.accuracy_score(y_test, prediction))
# Out:
# Accuracy: 0.5789473684210527
